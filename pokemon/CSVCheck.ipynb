# %%
import pandas as pd
import numpy as np

pm = pd.read_csv(r'C:\MLCourse\pokemon\PokemonUniteData.csv')
pm.head()
# Out:
#          Name                                        Description         Role  \
# 0   Trevenant  Add a Melee Defender to your UNITE team with a...     Defender
# 1       Absol  Absol is a Pokémon that can close the distance...    Speedster
# 2  Wigglytuff  Wigglytuff learns lots of moves that can stop ...    Supporter
# 3     Slowbro  No matter the situation, Slowbro goes about li...     Defender
# 4     Machamp  Machamp is a Pokémon that specializes in melee...  All-Rounder
#
#   Ranged_or_Melee UsageDifficulty  Offense  Endurance  Mobility  Scoring  \
# 0           Melee    Intermediate      2.0        4.0       2.0      2.5
# 1           Melee          Expert      3.5        2.0       4.0      2.5
# 2          Ranged    Intermediate      1.0        2.5       2.5      2.0
# 3          Ranged    Intermediate      1.5        4.0       1.5      1.5
# 4           Melee    Intermediate      4.0        2.5       2.5      2.5
#
#    Support
# 0      2.5
# 1      0.5
# 2      4.5
# ...

# %%
pm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             30 non-null     object
#  1   Description      30 non-null     object
#  2   Role             30 non-null     object
#  3   Ranged_or_Melee  30 non-null     object
#  4   UsageDifficulty  30 non-null     object
#  5   Offense          30 non-null     float64
#  6   Endurance        30 non-null     float64
#  7   Mobility         30 non-null     float64
#  8   Scoring          30 non-null     float64
#  9   Support          30 non-null     float64
# dtypes: float64(5), object(5)
# memory usage: 2.5+ KB

# %%
#PokemonUnite_df.to_csv(r'C:\Users\MY\Downloads\PokemonUniteData.csv', index = False)
